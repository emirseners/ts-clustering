# %% [markdown]
# # PySD usage
# This notebook shows how to run a simple Vensim model with PySD and feed results to `simclstr.clusterer`.
#
# MDL dosyasının bulunduğu yerde, path'de pycache ve py dosyaları oluşuyor, onları main kodda fonksiyonun altında silmek lazım.
#
# import sys'den model_path'e olan 4 satır package yayımlanmadan silinerek commented linelar kullanılmalıdır.

# %%
#from simclstr.clusterer import perform_clustering, simulate_from_vensim

#model_path = 'path/to/your/model.mdl'

import sys
sys.path.insert(0, "/Users/emirsener/Desktop/ts-clustering")

from simclstr.clusterer import perform_clustering, simulate_from_vensim
from simclstr.plotting import plot_clusters

import os
model_path = os.path.expanduser('~/Desktop/temperature model/temperature model.mdl')

parameter_set = {'Initial actual temperature': [15, 20, 25],
                 'Initial measured temperature': [15, 20, 25],
                 'Desired temperature': [15, 20, 25],
                 'Adjustment time': [3*i for i in range(1, 6)],
                 'Measurement delay': [3*i for i in range(1, 6)]
                }

output_of_interest = 'Actual Temperature'

simulation_results = simulate_from_vensim(model_path, parameter_set, output_of_interest)

for i, res in enumerate(simulation_results[:5]):
    print(f"Simulation Run {i+1}:")
    print(res)
    print("-" * 40)
# Out:
# Simulation Run 1:
# <simclstr.clusterer.TimeSeries object at 0x124206f90>
# ----------------------------------------
# Simulation Run 2:
# <simclstr.clusterer.TimeSeries object at 0x1242b3d90>
# ----------------------------------------
# Simulation Run 3:
# <simclstr.clusterer.TimeSeries object at 0x1231a6850>
# ----------------------------------------
# Simulation Run 4:
# <simclstr.clusterer.TimeSeries object at 0x125347820>
# ----------------------------------------
# Simulation Run 5:
# <simclstr.clusterer.TimeSeries object at 0x125347230>
# ----------------------------------------

# %%
clustering_results = perform_clustering(simulation_results, cMethod='maxclust', cValue = 8, plotDendrogram=True)

plot_clusters(clustering_results[1], 'pattern_dtw')

# %%
clustering_results = perform_clustering(simulation_results, distance='euclidean', cMethod='maxclust', cValue = 8, plotDendrogram=True, plotClusters=True)

plot_clusters(clustering_results[1], 'euclidean')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/Desktop/ts-clustering/simclstr/_distance_scipy.py:44, in _distance_scipy(list_of_ts_objects, metric, **kwargs)
#      43 try:
# ---> 44     dRow = pdist(data, metric=metric, **kwargs)
#      45 except Exception as e:
#
# File ~/Library/Python/3.13/lib/python/site-packages/scipy/spatial/distance.py:2300, in pdist(X, metric, out, **kwargs)
#    2299 n = X.shape[0]
# -> 2300 return xpx.lazy_apply(_np_pdist, X, out,
#    2301                       # lazy_apply doesn't support Array kwargs
#    2302                       kwargs.pop('w', None),
#    2303                       kwargs.pop('V', None),
#    2304                       kwargs.pop('VI', None),
#    2305                       # See src/distance_pybind.cpp::pdist
#    2306                       shape=((n * (n - 1)) // 2, ), dtype=X.dtype,
#    2307                       as_numpy=True, metric=metric, **kwargs)
#
# File ~/Library/Python/3.13/lib/python/site-packages/scipy/_lib/array_api_extra/_lib/_lazy.py:300, in lazy_apply(***failed resolving arguments***)
#     299     wrapped = _lazy_apply_wrapper(func, as_numpy, multi_output, xp)
# --> 300     out = wrapped(*args, **kwargs)
#     302 return out if multi_output else out[0]
#
# File ~/Library/Python/3.13/lib/python/site-packages/scipy/_lib/array_api_extra/_lib/_lazy.py:350, in _lazy_apply_wrapper.<locals>.wrapper(*args, **kwargs)
#     348 assert device is not None
# --> 350 out = func(*args_list, **kwargs)
#     352 if multi_output:
#
# File ~/Library/Python/3.13/lib/python/site-packages/scipy/spatial/distance.py:2338, in _np_pdist(X, out, w, V, VI, metric, **kwargs)
#    2337     pdist_fn = metric_info.pdist_func
# -> 2338     return pdist_fn(X, out=out, **kwargs)
#    2339 elif mstr.startswith("test_"):
#
# TypeError: pdist_euclidean(): incompatible function arguments. The following argument types are supported:
#     1. (x: object, w: object = None, out: object = None) -> numpy.ndarray
#
# Invoked with: array([[15., 15., 15., ..., 15., 15., 15.],
#        [15., 15., 15., ..., 15., 15., 15.],
#        [15., 15., 15., ..., 15., 15., 15.],
#        ...,
#        [25., 25., 25., ..., 25., 25., 25.],
#        [25., 25., 25., ..., 25., 25., 25.],
#        [25., 25., 25., ..., 25., 25., 25.]], shape=(675, 3201)); kwargs: out=None, plotClusters=True
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 clustering_results = perform_clustering(simulation_results, distance='euclidean', cMethod='maxclust', cValue = 8, plotDendrogram=True, plotClusters=True)
#       3 plot_clusters(clustering_results[1], 'euclidean')
#
# File ~/Desktop/ts-clustering/simclstr/clusterer.py:243, in perform_clustering(list_of_ts_objects, distance, interClusterDistance, cMethod, cValue, plotDendrogram, **kwargs)
#     240 # Construct a list with distances. This list is the upper triangle of the distance matrix
#     241 try:
#     242     # Filter out parameters that are not meant for distance functions
# --> 243     dRow, list_of_ts_objects_with_fv = _distance_functions[distance](list_of_ts_objects, **kwargs)
#     244 except KeyError:
#     245     print(f'Unknown distance "{distance}" is used.')
#
# File ~/Desktop/ts-clustering/simclstr/clusterer.py:27, in <lambda>(data, **kwargs)
#      19 import pysd
#      20 import itertools
#      22 _distance_functions: Dict[str, Callable] = {
#      23     'pattern': _distance_pattern,
#      24     'pattern_dtw': _distance_pattern_dtw,
#      25     'dtw': _distance_dtw,
#      26     'scipy': _distance_scipy,
# ---> 27     'euclidean': lambda data, **kwargs: _distance_scipy(data, metric='euclidean', **kwargs),
#      28     'minkowski': lambda data, **kwargs: _distance_scipy(data, metric='minkowski', **kwargs),
#      29     'cityblock': lambda data, **kwargs: _distance_scipy(data, metric='cityblock', **kwargs),
#      30     'seuclidean': lambda data, **kwargs: _distance_scipy(data, metric='seuclidean', **kwargs),
#      31     'sqeuclidean': lambda data, **kwargs: _distance_scipy(data, metric='sqeuclidean', **kwargs),
#      32     'cosine': lambda data, **kwargs: _distance_scipy(data, metric='cosine', **kwargs),
#      33     'correlation': lambda data, **kwargs: _distance_scipy(data, metric='correlation', **kwargs),
#      34     'hamming': lambda data, **kwargs: _distance_scipy(data, metric='hamming', **kwargs),
#      35     'jaccard': lambda data, **kwargs: _distance_scipy(data, metric='jaccard', **kwargs),
#      36     'jensenshannon': lambda data, **kwargs: _distance_scipy(data, metric='jensenshannon', **kwargs),
#      37     'chebyshev': lambda data, **kwargs: _distance_scipy(data, metric='chebyshev', **kwargs),
#      38     'canberra': lambda data, **kwargs: _distance_scipy(data, metric='canberra', **kwargs),
#      39     'braycurtis': lambda data, **kwargs: _distance_scipy(data, metric='braycurtis', **kwargs),
#      40     'mahalanobis': lambda data, **kwargs: _distance_scipy(data, metric='mahalanobis', **kwargs),
#      41     'yule': lambda data, **kwargs: _distance_scipy(data, metric='yule', **kwargs),
#      42     'matching': lambda data, **kwargs: _distance_scipy(data, metric='matching', **kwargs),
#      43     'dice': lambda data, **kwargs: _distance_scipy(data, metric='dice', **kwargs),
#      44     'rogerstanimoto': lambda data, **kwargs: _distance_scipy(data, metric='rogerstanimoto', **kwargs),
#      45     'russellrao': lambda data, **kwargs: _distance_scipy(data, metric='russellrao', **kwargs),
#      46     'sokalsneath': lambda data, **kwargs: _distance_scipy(data, metric='sokalsneath', **kwargs),
#      47     'kulczynski1': lambda data, **kwargs: _distance_scipy(data, metric='kulczynski1', **kwargs)
#      48 }
#      50 def read_time_series(file_path: str, withClusters: bool = False) -> List['TimeSeries']:
#      51     """
#      52     Import time series data from .xlsx or .csv files.
#      53
#    (...)    100         List of TimeSeries objects.
#     101     """
#
# File ~/Desktop/ts-clustering/simclstr/_distance_scipy.py:46, in _distance_scipy(list_of_ts_objects, metric, **kwargs)
#      44     dRow = pdist(data, metric=metric, **kwargs)
#      45 except Exception as e:
# ---> 46     raise ValueError(f"Error computing {metric} distance: {str(e)}. "
#      47                    f"Please check that the metric '{metric}' is supported by scipy and "
#      48                    f"required parameters are provided.")
#      50 return dRow, list_of_ts_objects
#
# ValueError: Error computing euclidean distance: pdist_euclidean(): incompatible function arguments. The following argument types are supported:
#     1. (x: object, w: object = None, out: object = None) -> numpy.ndarray
#
# Invoked with: array([[15., 15., 15., ..., 15., 15., 15.],
#        [15., 15., 15., ..., 15., 15., 15.],
#        [15., 15., 15., ..., 15., 15., 15.],
#        ...,
#        [25., 25., 25., ..., 25., 25., 25.],
#        [25., 25., 25., ..., 25., 25., 25.],
#        [25., 25., 25., ..., 25., 25., 25.]], shape=(675, 3201)); kwargs: out=None, plotClusters=True. Please check that the metric 'euclidean' is supported by scipy and required parameters are provided.
